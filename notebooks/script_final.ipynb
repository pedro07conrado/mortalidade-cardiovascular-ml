# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Carregar o Dataset Final
df = pd.read_parquet('../data/gold/dataset_modelagem.parquet')

print(f"✅ Dataset Carregado: {df.shape[0]} linhas e {df.shape[1]} colunas")

# --- CHECKLIST DO PROFESSOR ---

print("\n=== 1. ANÁLISE DE CONFUSÃO (Validação H1) ===")
# Verifica se a variável de envelhecimento existe
if 'tx_envelhecimento' in df.columns:
    print(f"Variável 'tx_envelhecimento' presente? SIM")
    
    # Matriz de Correlação Focada
    cols_confusao = ['taxa_mortalidade', 'idhm', 'tx_envelhecimento']
    corr = df[cols_confusao].corr()
    print("\nMatriz de Correlação:")
    print(corr.round(4))
    
    print("\nInterpretação Automática:")
    print(f"-> Correlação IDHM vs Mortalidade: {corr.loc['idhm', 'taxa_mortalidade']:.4f} (H1 Refutada?)")
    print(f"-> Correlação IDHM vs Envelhecimento: {corr.loc['idhm', 'tx_envelhecimento']:.4f} (Ricos são mais velhos?)")
    print(f"-> Correlação Envelhecimento vs Mortalidade: {corr.loc['tx_envelhecimento', 'taxa_mortalidade']:.4f} (Velhice causa morte?)")
else:
    print("❌ ALERTA: Variável 'tx_envelhecimento' NÃO ENCONTRADA!")

print("\n=== 2. VARIÁVEL TARGET (Distribuição) ===")
# Cria a classe simulada (Cutoff 150)
target = (df['taxa_mortalidade'] >= 150).astype(int)
contagem = target.value_counts()
percentual = target.value_counts(normalize=True) * 100

print(f"Distribuição da Classe (Corte 150):")
print(f"Classe 0 (Baixo Risco): {contagem[0]} ({percentual[0]:.1f}%)")
print(f"Classe 1 (Alto Risco):  {contagem[1]} ({percentual[1]:.1f}%)")

print("\n=== 3. CHECKLIST TÉCNICO ===")
print(f"- Total de Linhas: {len(df)}")
print(f"- Cidades Únicas: {df['codmun'].nunique()}")
print(f"- Nulos no IDHM: {df['idhm'].isnull().sum()}")
print(f"- Nulos na Renda: {df['renda_pc'].isnull().sum()}")

# Validação do cálculo da taxa (Engenharia Reversa)
# Recalcula para ver se bate com a coluna existente
check_taxa = (df['mortes_cardio'] / df['populacao']) * 100000
diff = (df['taxa_mortalidade'] - check_taxa).abs().max()
print(f"- Erro máximo no cálculo da taxa: {diff:.5f} (Deve ser zero)")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 import matplotlib.pyplot as plt
#       5 # 1. Carregar o Dataset Final
# ----> 6 df = pd.read_parquet('../data/gold/dataset_tcc_modelagem.parquet')
#       8 print(f"✅ Dataset Carregado: {df.shape[0]} linhas e {df.shape[1]} colunas")
#      10 # --- CHECKLIST DO PROFESSOR ---
#
# File ~/mortalidade-cardiovascular-ml/venv/lib/python3.10/site-packages/pandas/io/parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
# ...
